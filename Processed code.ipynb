# %%
import pandas as pd

# %%
# how to inout your directory
# open the fike location first and copy address
# 

sales = pd.read_csv('C:/Users/user/Desktop/aji/DataSet_final/FactInternetSales.csv')

# %%
sales.head
# Out:
# <bound method NDFrame.head of        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0             310      20101229    20110110     20110105        21768
# 1             346      20101229    20110110     20110105        28389
# 2             346      20101229    20110110     20110105        25863
# 3             336      20101229    20110110     20110105        14501
# 4             346      20101229    20110110     20110105        11003
# ...           ...           ...         ...          ...          ...
# 60393         485      20140128    20140209     20140204        15868
# 60394         225      20140128    20140209     20140204        15868
# 60395         485      20140128    20140209     20140204        18759
# 60396         486      20140128    20140209     20140204        18759
# 60397         225      20140128    20140209     20140204        18759
#
#        PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0                 1           19                  6          SO43697
# 1                 1           39                  7          SO43698
# 2                 1          100                  1          SO43699
# 3                 1          100                  4          SO43700
# 4                 1            6                  9          SO43701
# ...             ...          ...                ...              ...
# 60393             1          100                  6          SO75122
# 60394             1          100                  6          SO75122
# 60395             1          100                  6          SO75123
# 60396             1          100                  6          SO75123
# 60397             1          100                  6          SO75123
#
#        SalesOrderLineNumber  ...  ProductStandardCost  TotalProductCost  \
# 0                         1  ...            2171.2942         2171.2942
# 1                         1  ...            1912.1544         1912.1544
# 2                         1  ...            1912.1544         1912.1544
# 3                         1  ...             413.1463          413.1463
# 4                         1  ...            1912.1544         1912.1544
# ...                     ...  ...                  ...               ...
# 60393                     1  ...               8.2205            8.2205
# 60394                     2  ...               6.9223            6.9223
# 60395                     1  ...               8.2205            8.2205
# 60396                     2  ...              59.4660           59.4660
# 60397                     3  ...               6.9223            6.9223
#
#        SalesAmount    TaxAmt  Freight  CarrierTrackingNumber  \
# 0        3578.2700  286.2616  89.4568                    NaN
# 1        3399.9900  271.9992  84.9998                    NaN
# 2        3399.9900  271.9992  84.9998                    NaN
# 3         699.0982   55.9279  17.4775                    NaN
# 4        3399.9900  271.9992  84.9998                    NaN
# ...            ...       ...      ...                    ...
# 60393      21.9800    1.7584   0.5495                    NaN
# 60394       8.9900    0.7192   0.2248                    NaN
# 60395      21.9800    1.7584   0.5495                    NaN
# 60396     159.0000   12.7200   3.9750                    NaN
# 60397       8.9900    0.7192   0.2248                    NaN
#
#        CustomerPONumber                OrderDate                  DueDate  \
# 0                   NaN  2010-12-29 00:00:00.000  2011-01-10 00:00:00.000
# 1                   NaN  2010-12-29 00:00:00.000  2011-01-10 00:00:00.000
# 2                   NaN  2010-12-29 00:00:00.000  2011-01-10 00:00:00.000
# 3                   NaN  2010-12-29 00:00:00.000  2011-01-10 00:00:00.000
# 4                   NaN  2010-12-29 00:00:00.000  2011-01-10 00:00:00.000
# ...                 ...                      ...                      ...
# 60393               NaN  2014-01-28 00:00:00.000  2014-02-09 00:00:00.000
# 60394               NaN  2014-01-28 00:00:00.000  2014-02-09 00:00:00.000
# 60395               NaN  2014-01-28 00:00:00.000  2014-02-09 00:00:00.000
# 60396               NaN  2014-01-28 00:00:00.000  2014-02-09 00:00:00.000
# 60397               NaN  2014-01-28 00:00:00.000  2014-02-09 00:00:00.000
#
#                       ShipDate
# 0      2011-01-05 00:00:00.000
# 1      2011-01-05 00:00:00.000
# 2      2011-01-05 00:00:00.000
# 3      2011-01-05 00:00:00.000
# 4      2011-01-05 00:00:00.000
# ...                        ...
# 60393  2014-02-04 00:00:00.000
# 60394  2014-02-04 00:00:00.000
# 60395  2014-02-04 00:00:00.000
# 60396  2014-02-04 00:00:00.000
# 60397  2014-02-04 00:00:00.000
#
# [60398 rows x 26 columns]>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
sales.shape
# Out:
# (60398, 26)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             60398 non-null  int64
#  1   OrderDateKey           60398 non-null  int64
#  2   DueDateKey             60398 non-null  int64
#  3   ShipDateKey            60398 non-null  int64
#  4   CustomerKey            60398 non-null  int64
#  5   PromotionKey           60398 non-null  int64
#  6   CurrencyKey            60398 non-null  int64
#  7   SalesTerritoryKey      60398 non-null  int64
#  8   SalesOrderNumber       60398 non-null  object
#  9   SalesOrderLineNumber   60398 non-null  int64
#  10  RevisionNumber         60398 non-null  int64
#  11  OrderQuantity          60398 non-null  int64
#  12  UnitPrice              60398 non-null  float64
#  13  ExtendedAmount         60398 non-null  float64
#  14  UnitPriceDiscountPct   60398 non-null  int64
#  15  DiscountAmount         60398 non-null  int64
#  16  ProductStandardCost    60398 non-null  float64
#  17  TotalProductCost       60398 non-null  float64
#  18  SalesAmount            60398 non-null  float64
#  19  TaxAmt                 60398 non-null  float64
#  20  Freight                60398 non-null  float64
#  21  CarrierTrackingNumber  0 non-null      float64
#  22  CustomerPONumber       0 non-null      float64
#  23  OrderDate              60398 non-null  object
#  24  DueDate                60398 non-null  object
#  25  ShipDate               60398 non-null  object
# dtypes: float64(9), int64(13), object(4)
# memory usage: 12.0+ MB

# %%
sales.describe()
# Out:
#          ProductKey  OrderDateKey    DueDateKey   ShipDateKey   CustomerKey  \
# count  60398.000000  6.039800e+04  6.039800e+04  6.039800e+04  60398.000000
# mean     437.557932  2.012973e+07  2.013010e+07  2.012994e+07  18841.685420
# std      118.088390  4.745050e+03  4.985453e+03  4.851061e+03   5432.430404
# min      214.000000  2.010123e+07  2.011011e+07  2.011010e+07  11000.000000
# 25%      359.000000  2.013040e+07  2.013042e+07  2.013041e+07  14003.000000
# 50%      479.000000  2.013071e+07  2.013073e+07  2.013072e+07  18143.000000
# 75%      529.000000  2.013102e+07  2.013103e+07  2.013102e+07  23429.750000
# max      606.000000  2.014013e+07  2.014021e+07  2.014020e+07  29483.000000
#
#        PromotionKey   CurrencyKey  SalesTerritoryKey  SalesOrderLineNumber  \
# count  60398.000000  60398.000000       60398.000000          60398.000000
# mean       1.041839     69.845326           6.244462              1.886321
# std        0.342605     42.146363           2.961150              1.016328
# min        1.000000      6.000000           1.000000              1.000000
# 25%        1.000000     19.000000           4.000000              1.000000
# 50%        1.000000    100.000000           7.000000              2.000000
# 75%        1.000000    100.000000           9.000000              2.000000
# max       14.000000    100.000000          10.000000              8.000000
#
#        RevisionNumber  ...  ExtendedAmount  UnitPriceDiscountPct  \
# count         60398.0  ...    60398.000000               60398.0
# mean              1.0  ...      486.086911                   0.0
# std               0.0  ...      928.489892                   0.0
# min               1.0  ...        2.290000                   0.0
# 25%               1.0  ...        7.950000                   0.0
# 50%               1.0  ...       29.990000                   0.0
# 75%               1.0  ...      539.990000                   0.0
# max               1.0  ...     3578.270000                   0.0
#
#        DiscountAmount  ProductStandardCost  TotalProductCost   SalesAmount  \
# count         60398.0         60398.000000      60398.000000  60398.000000
# mean              0.0           286.065657        286.065657    486.086911
# std               0.0           552.457641        552.457641    928.489892
# min               0.0             0.856500          0.856500      2.290000
# 25%               0.0             2.973300          2.973300      7.950000
# 50%               0.0            11.216300         11.216300     29.990000
# 75%               0.0           294.579700        294.579700    539.990000
# max               0.0          2171.294200       2171.294200   3578.270000
#
#              TaxAmt       Freight  CarrierTrackingNumber  CustomerPONumber
# count  60398.000000  60398.000000                    0.0               0.0
# mean      38.886954     12.152217                    NaN               NaN
# std       74.279193     23.212248                    NaN               NaN
# min        0.183200      0.057300                    NaN               NaN
# 25%        0.636000      0.198800                    NaN               NaN
# 50%        2.399200      0.749800                    NaN               NaN
# 75%       43.199200     13.499800                    NaN               NaN
# max      286.261600     89.456800                    NaN               NaN
#
# [8 rows x 22 columns]

# %%
sales['TotalProductCost'].mean()
# Out:
# 286.06565740089184

# %%
sales['TotalProductCost'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['TotalProductCost'].plot(kind='density', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ax = sales['TotalProductCost'].plot(kind='density', figsize=(14,6))
ax.axvline(sales['TotalProductCost'].mean(), color = 'red')
ax.axvline(sales['TotalProductCost'].median(), color='green')

# %%
af = sales['TotalProductCost'].plot(kind='hist', figsize=(14,6))
af.set_ylabel('Number of sales')
af.set_xlabel('dollars')
# Out:
# Text(0.5, 0, 'dollars')

# %%
corr = sales.corr()
corr
# Out:
#                        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  \
# ProductKey               1.000000      0.231750    0.219959     0.225845
# OrderDateKey             0.231750      1.000000    0.941479     0.965982
# DueDateKey               0.219959      0.941479    1.000000     0.973241
# ShipDateKey              0.225845      0.965982    0.973241     1.000000
# CustomerKey              0.052217     -0.001774    0.001979    -0.001942
# PromotionKey             0.020898     -0.014860   -0.015908    -0.015849
# CurrencyKey             -0.001683      0.110514    0.108257     0.111758
# SalesTerritoryKey       -0.023684     -0.055401   -0.051429    -0.053084
# SalesOrderLineNumber    -0.248350      0.230817    0.222521     0.227242
# RevisionNumber                NaN           NaN         NaN          NaN
# OrderQuantity                 NaN           NaN         NaN          NaN
# UnitPrice               -0.142207     -0.644948   -0.611970    -0.630441
# ExtendedAmount          -0.142207     -0.644948   -0.611970    -0.630441
# UnitPriceDiscountPct          NaN           NaN         NaN          NaN
# DiscountAmount                NaN           NaN         NaN          NaN
# ProductStandardCost     -0.132349     -0.645423   -0.612555    -0.630975
# TotalProductCost        -0.132349     -0.645423   -0.612555    -0.630975
# SalesAmount             -0.142207     -0.644948   -0.611970    -0.630441
# TaxAmt                  -0.142207     -0.644948   -0.611970    -0.630441
# Freight                 -0.142207     -0.644948   -0.611969    -0.630440
# CarrierTrackingNumber         NaN           NaN         NaN          NaN
# CustomerPONumber              NaN           NaN         NaN          NaN
#
#                        CustomerKey  PromotionKey  CurrencyKey  \
# ProductKey                0.052217      0.020898    -0.001683
# OrderDateKey             -0.001774     -0.014860     0.110514
# DueDateKey                0.001979     -0.015908     0.108257
# ShipDateKey              -0.001942     -0.015849     0.111758
# CustomerKey               1.000000      0.014025     0.099390
# PromotionKey              0.014025      1.000000    -0.001344
# CurrencyKey               0.099390     -0.001344     1.000000
# SalesTerritoryKey        -0.050912      0.002893    -0.434895
# SalesOrderLineNumber     -0.017838     -0.025094     0.037910
# RevisionNumber                 NaN           NaN          NaN
# OrderQuantity                  NaN           NaN          NaN
# UnitPrice                -0.035415      0.070681    -0.062022
# ExtendedAmount           -0.035415      0.070681    -0.062022
# UnitPriceDiscountPct           NaN           NaN          NaN
# DiscountAmount                 NaN           NaN          NaN
# ProductStandardCost      -0.023599      0.068746    -0.063455
# TotalProductCost         -0.023599      0.068746    -0.063455
# SalesAmount              -0.035415      0.070681    -0.062022
# TaxAmt                   -0.035415      0.070681    -0.062022
# Freight                  -0.035415      0.070681    -0.062022
# CarrierTrackingNumber          NaN           NaN          NaN
# CustomerPONumber               NaN           NaN          NaN
#
#                        SalesTerritoryKey  SalesOrderLineNumber  \
# ProductKey                     -0.023684             -0.248350
# OrderDateKey                   -0.055401              0.230817
# DueDateKey                     -0.051429              0.222521
# ShipDateKey                    -0.053084              0.227242
# CustomerKey                    -0.050912             -0.017838
# PromotionKey                    0.002893             -0.025094
# CurrencyKey                    -0.434895              0.037910
# SalesTerritoryKey               1.000000             -0.008030
# SalesOrderLineNumber           -0.008030              1.000000
# RevisionNumber                       NaN                   NaN
# OrderQuantity                        NaN                   NaN
# UnitPrice                       0.073906             -0.430759
# ExtendedAmount                  0.073906             -0.430759
# UnitPriceDiscountPct                 NaN                   NaN
# DiscountAmount                       NaN                   NaN
# ProductStandardCost             0.075988             -0.430635
# TotalProductCost                0.075988             -0.430635
# SalesAmount                     0.073906             -0.430759
# TaxAmt                          0.073906             -0.430759
# Freight                         0.073906             -0.430759
# CarrierTrackingNumber                NaN                   NaN
# CustomerPONumber                     NaN                   NaN
#
#                        RevisionNumber  ...  ExtendedAmount  \
# ProductKey                        NaN  ...       -0.142207
# OrderDateKey                      NaN  ...       -0.644948
# DueDateKey                        NaN  ...       -0.611970
# ShipDateKey                       NaN  ...       -0.630441
# CustomerKey                       NaN  ...       -0.035415
# PromotionKey                      NaN  ...        0.070681
# CurrencyKey                       NaN  ...       -0.062022
# SalesTerritoryKey                 NaN  ...        0.073906
# SalesOrderLineNumber              NaN  ...       -0.430759
# RevisionNumber                    NaN  ...             NaN
# OrderQuantity                     NaN  ...             NaN
# UnitPrice                         NaN  ...        1.000000
# ExtendedAmount                    NaN  ...        1.000000
# UnitPriceDiscountPct              NaN  ...             NaN
# DiscountAmount                    NaN  ...             NaN
# ProductStandardCost               NaN  ...        0.997845
# TotalProductCost                  NaN  ...        0.997845
# SalesAmount                       NaN  ...        1.000000
# TaxAmt                            NaN  ...        1.000000
# Freight                           NaN  ...        1.000000
# CarrierTrackingNumber             NaN  ...             NaN
# CustomerPONumber                  NaN  ...             NaN
#
#                        UnitPriceDiscountPct  DiscountAmount  \
# ProductKey                              NaN             NaN
# OrderDateKey                            NaN             NaN
# DueDateKey                              NaN             NaN
# ShipDateKey                             NaN             NaN
# CustomerKey                             NaN             NaN
# PromotionKey                            NaN             NaN
# CurrencyKey                             NaN             NaN
# SalesTerritoryKey                       NaN             NaN
# SalesOrderLineNumber                    NaN             NaN
# RevisionNumber                          NaN             NaN
# OrderQuantity                           NaN             NaN
# UnitPrice                               NaN             NaN
# ExtendedAmount                          NaN             NaN
# UnitPriceDiscountPct                    NaN             NaN
# DiscountAmount                          NaN             NaN
# ProductStandardCost                     NaN             NaN
# TotalProductCost                        NaN             NaN
# SalesAmount                             NaN             NaN
# TaxAmt                                  NaN             NaN
# Freight                                 NaN             NaN
# CarrierTrackingNumber                   NaN             NaN
# CustomerPONumber                        NaN             NaN
#
#                        ProductStandardCost  TotalProductCost  SalesAmount  \
# ProductKey                       -0.132349         -0.132349    -0.142207
# OrderDateKey                     -0.645423         -0.645423    -0.644948
# DueDateKey                       -0.612555         -0.612555    -0.611970
# ShipDateKey                      -0.630975         -0.630975    -0.630441
# CustomerKey                      -0.023599         -0.023599    -0.035415
# PromotionKey                      0.068746          0.068746     0.070681
# CurrencyKey                      -0.063455         -0.063455    -0.062022
# SalesTerritoryKey                 0.075988          0.075988     0.073906
# SalesOrderLineNumber             -0.430635         -0.430635    -0.430759
# RevisionNumber                         NaN               NaN          NaN
# OrderQuantity                          NaN               NaN          NaN
# UnitPrice                         0.997845          0.997845     1.000000
# ExtendedAmount                    0.997845          0.997845     1.000000
# UnitPriceDiscountPct                   NaN               NaN          NaN
# DiscountAmount                         NaN               NaN          NaN
# ProductStandardCost               1.000000          1.000000     0.997845
# TotalProductCost                  1.000000          1.000000     0.997845
# SalesAmount                       0.997845          0.997845     1.000000
# TaxAmt                            0.997845          0.997845     1.000000
# Freight                           0.997845          0.997845     1.000000
# CarrierTrackingNumber                  NaN               NaN          NaN
# CustomerPONumber                       NaN               NaN          NaN
#
#                          TaxAmt   Freight  CarrierTrackingNumber  \
# ProductKey            -0.142207 -0.142207                    NaN
# OrderDateKey          -0.644948 -0.644948                    NaN
# DueDateKey            -0.611970 -0.611969                    NaN
# ShipDateKey           -0.630441 -0.630440                    NaN
# CustomerKey           -0.035415 -0.035415                    NaN
# PromotionKey           0.070681  0.070681                    NaN
# CurrencyKey           -0.062022 -0.062022                    NaN
# SalesTerritoryKey      0.073906  0.073906                    NaN
# SalesOrderLineNumber  -0.430759 -0.430759                    NaN
# RevisionNumber              NaN       NaN                    NaN
# OrderQuantity               NaN       NaN                    NaN
# UnitPrice              1.000000  1.000000                    NaN
# ExtendedAmount         1.000000  1.000000                    NaN
# UnitPriceDiscountPct        NaN       NaN                    NaN
# DiscountAmount              NaN       NaN                    NaN
# ProductStandardCost    0.997845  0.997845                    NaN
# TotalProductCost       0.997845  0.997845                    NaN
# SalesAmount            1.000000  1.000000                    NaN
# TaxAmt                 1.000000  1.000000                    NaN
# Freight                1.000000  1.000000                    NaN
# CarrierTrackingNumber       NaN       NaN                    NaN
# CustomerPONumber            NaN       NaN                    NaN
#
#                        CustomerPONumber
# ProductKey                          NaN
# OrderDateKey                        NaN
# DueDateKey                          NaN
# ShipDateKey                         NaN
# CustomerKey                         NaN
# PromotionKey                        NaN
# CurrencyKey                         NaN
# SalesTerritoryKey                   NaN
# SalesOrderLineNumber                NaN
# RevisionNumber                      NaN
# OrderQuantity                       NaN
# UnitPrice                           NaN
# ExtendedAmount                      NaN
# UnitPriceDiscountPct                NaN
# DiscountAmount                      NaN
# ProductStandardCost                 NaN
# TotalProductCost                    NaN
# SalesAmount                         NaN
# TaxAmt                              NaN
# Freight                             NaN
# CarrierTrackingNumber               NaN
# CustomerPONumber                    NaN
#
# [22 rows x 22 columns]

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
sales.plot(kind='scatter', x='TotalProductCost', y='SalesAmount', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='TotalProductCost', ylabel='SalesAmount'>

# %%
sales['Profit'] = sales['SalesAmount'] - sales['TotalProductCost'] - sales['TaxAmt']

sales['Profit'].head
# Out:
# <bound method NDFrame.head of 0        1120.7142
# 1        1215.8364
# 2        1215.8364
# 3         230.0240
# 4        1215.8364
#            ...
# 60393      12.0011
# 60394       1.3485
# 60395      12.0011
# 60396      86.8140
# 60397       1.3485
# Name: Profit, Length: 60398, dtype: float64>

# %%
sales.plot(kind='scatter', x='TotalProductCost', y='Profit', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='TotalProductCost', ylabel='Profit'>

# %%
sales['Profit'].plot(kind='hist', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
x = sales[['TotalProductCost', 'TaxAmt']]
y = sales['SalesAmount']
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size =0.2, random_state=10)
clf.fit(x_train,y_train)
clf.predict(x_test)
# Out:
# array([  32.59999331,    4.98999792,   21.48999516, ..., 2181.56248188,
#          49.99000403, 2181.56248188])

# %%
import joblib
joblib.dump(clf, 'price-predictor.joblib')
model = joblib.load('price-predictor.joblib')
prediction = model.predict([[1000, 100]])
prediction
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1250.00015662])
